# %% [markdown]
# [Smithsonian Open Access] (https://www.si.edu/openaccess), allows us to download, share, and reuse millions of the Smithsonian’s images and data from across the Smithsonian’s 19 museums, nine research centers, libraries, archives, and the National Zoo.
#
# This notebook introduces how to explore the repository and create a CSV dataset. In additon, this example applies computer vision methods in achieve face detection which has gained relevance especially in fields like photography and marketing.
#
# The Open Access API requires an API key to access the endpoints. Please register with https://api.data.gov/signup/ to get a key.

# %% [markdown]
# ## Setting up things

# %%
import requests, csv
import json
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Global configuration
#
# In this section, we can add our api_key, the text that we want to use to search and retrieve the elements, and the number of records to retrieve.

# %%
api_key = 'L20kTDAWj35bazo1Zhwx8wN5Ua0zKmhHz8PtIacX' # add your own api_key
q = 'theodore roosevelt' # querystring
rows = '100' # number of records to retrieve

# %% [markdown]
# ## Accesssing Smithsonian repository
# Please visit https://edan.si.edu/openaccess/apidocs/#api-search-search for more information.

# %%
url = 'https://api.si.edu/openaccess/api/v1.0/search'
r = requests.get(url, params = {'q': q, 'start':'0', 'rows': rows, 'api_key': api_key })
print(r.url)
response = r.text
# Out:
# https://api.si.edu/openaccess/api/v1.0/search?q=theodore+roosevelt&start=0&rows=100&api_key=L20kTDAWj35bazo1Zhwx8wN5Ua0zKmhHz8PtIacX

# %% [markdown]
# ### Creating a csv file

# %%
csv_out = csv.writer(open('si_records.csv', 'w'), delimiter = ',', quotechar = '"', quoting = csv.QUOTE_MINIMAL)
csv_out.writerow(['title', 'date', 'media_usage', 'data_source', 'dimensions', 'sitter', 'type', 'medium', 'artist', 'link'])
# Out:
# 78

# %% [markdown]
# ### Reading the results and retrieving the metadata

# %%
results = json.loads(response)

for r in results['response']['rows']:
    print(r['id'] + ' ' +  r['title'])
    
    # getting the identifiers of the records to access the IIIF manifests
    try:
        for i in range(len(r['content']['descriptiveNonRepeating']['online_media']['media'])):
            idsId = r['content']['descriptiveNonRepeating']['online_media']['media'][i]['idsId']
            print(idsId)

            # retrieving the manifest
            iiifUrl = 'https://ids.si.edu/ids/manifest/' + idsId
            iiifItemResponse = requests.get(iiifUrl)

            iiifItem = json.loads(iiifItemResponse.text)

            # retrieving metadata
            title = date = licence = datasource = dimensions = sitter = typem = medium = artist = link =''

            for i in iiifItem['metadata']:
                if i['label'] == 'Title':
                    title = i['value']
                elif i['label'] == 'Date':
                    date = i['value']
                elif i['label'] == 'Media Usage':
                    licence = i['value']
                elif i['label'] == 'Data Source':
                    datasource = i['value']
                elif i['label'] == 'Dimensions':
                    dimensions = i['value']
                elif i['label'] == 'Sitter':
                    sitter = i['value']
                elif i['label'] == 'Type':
                    typem = i['value']
                elif i['label'] == 'Medium':    
                    medium = i['value']
                elif i['label'] == 'Artist':    
                    artist = i['value']
                else: pass

            csv_out.writerow([title,date,licence,datasource,dimensions,sitter,typem,medium,artist,iiifUrl])

    except:
        print("An exception occurred")
# Out:
# edanmdm-npg_S_NPG.77.223 Theodore Roosevelt
# NPG-S-NPG_77_223
# edanmdm-npg_NPG.88.4.H Theodore Roosevelt
# An exception occurred
# edanmdm-npg_NPG.81.53 Theodore Roosevelt
# NPG-NPG_81_53
# edanmdm-npg_NPG.81.125 Theodore Roosevelt
# NPG-NPG_81_125
# edanmdm-npg_NPG.81.163 Theodore Roosevelt
# NPG-NPG_81_163
# edanmdm-npg_S_NPG.77.41 Theodore Roosevelt
# NPG-S-NPG_77_41
# edanmdm-npg_NPG.81.131 Theodore Roosevelt
# NPG-NPG_81_131
# edanmdm-npg_S_NPG.84.285 Theodore Roosevelt
# NPG-S-NPG_84_285
# edanmdm-npg_NPG.80.57 Theodore Roosevelt
# NPG-8000114B_1
# edanmdm-npg_NPG.91.21 Theodore Roosevelt
# NPG-NPG_91_21
# edanmdm-npg_NPG.97.198 Theodore Roosevelt
# NPG-NPG_97_198
# edanmdm-npg_NPG.99.32 Theodore Roosevelt
# NPG-NPG_99_32
# edanmdm-npg_NPG.2004.8 Theodore Roosevelt
# NPG-A4000016B_1
# edanmdm-npg_S_NPG.84.296 Theodore Roosevelt and Frank J. Hogan
# NPG-S-NPG_84_296
# edanmdm-npg_AD_NPG.78.4 His Master's Voice
# NPG-AD-NPG_78_4
# edanmdm-npg_NPG.92.95 Teddy Roosevelt and Oscar Edward Cesare
# NPG-NPG_92_95
# edanmdm-npg_S_NPG.81.39 Theodore Roosevelt and Albert Beveridge
# NPG-8110070C
# edanmdm-npg_NPG.81.122 Theodore Roosevelt
# NPG-8100242C_2
# edanmdm-npg_NPG.81.127 Theodore Roosevelt
# NPG-NPG_81_127
# edanmdm-npg_NPG.81.132 Theodore Roosevelt
# NPG-NPG_81_132
# edanmdm-npg_NPG.81.135 Theodore Roosevelt
# NPG-NPG_81_135
# edanmdm-npg_NPG.81.171 Theodore Roosevelt
# NPG-NPG_81_171
# edanmdm-npg_S_NPG.91.214 Theodore Roosevelt
# NPG-S-NPG_91_214
# edanmdm-npg_NPG.87.288.N Theodore Roosevelt
# NPG-NPG_87_288_n
# edanmdm-npg_NPG.81.124 Theodore Roosevelt
# NPG-NPG_81_124
# edanmdm-npg_S_NPG.80.19 Theodore Roosevelt, John Milton Hay, Joseph Gurney Cannon
# NPG-S-NPG_80_19
# edanmdm-npg_NPG.81.133 Theodore Roosevelt
# NPG-NPG_81_133
# edanmdm-npg_NPG.81.134 Theodore Roosevelt
# NPG-NPG_81_134
# edanmdm-npg_NPG.81.130 Theodore Roosevelt
# NPG-NPG_81_130
# edanmdm-npg_NPG.96.116 Made Harmless at Last
# NPG-NPG_96_116
# edanmdm-npg_NPG.2002.376 Theodore Roosevelt
# NPG-A2000852C_1
# NPG-A2000852C_2
# edanmdm-nmah_513979 Conservation of Theodore Roosevelt Memorial Window
# An exception occurred
# edanmdm-nmah_513980 Theodore Roosevelt as Author and Contributor
# An exception occurred
# edanmdm-nmah_513988 Theodore Roosevelt, the Man as I Knew Him
# An exception occurred
# edanmdm-nmah_513989 Theodore Roosevelt, the Logic of His Career
# An exception occurred
# edanmdm-nmah_700120 Theodore Roosevelt As the Radium Man
# An exception occurred
# edanmdm-nmah_529296 Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_513976 Theodore Roosevelt the Child
# An exception occurred
# edanmdm-nmah_513981 Address of Hon Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_513991 Theodore Roosevelt, a Verse Sequence
# An exception occurred
# edanmdm-nmah_1591218 Theodore Roosevelt Plaque, United States, early 20th century
# An exception occurred
# edanmdm-npg_S_NPG.76.64 Theodore Roosevelt
# NPG-7610134B_1
# edanmdm-nmah_507438 Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_503011 Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_503049 Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_520746 Speech of Col. Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_531152 Theodore Roosevelt
# An exception occurred
# edanmdm-siris_sil_23261 My brother, Theodore Roosevelt, by Corinne Roosevelt Robinson ..
# An exception occurred
# edanmdm-siris_arc_217625 Theodore Roosevelt Collection, circa 1901-1928, 1933, 1936 and 1958 Newspaper Clippings
# An exception occurred
# edanmdm-nmah_782837 Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_1173958 Theodore Roosevelt The Citizen
# An exception occurred
# edanmdm-nmah_1896708 Theodore Roosevelt "100% American"
# An exception occurred
# edanmdm-nmah_1896863 The Works of Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_1897206 The Works of Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_1896881 Theodore Roosevelt the Boy and the Man
# An exception occurred
# edanmdm-nmah_1897043 The Life of Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_1897352 Life and Work of Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_1215327 Crate used by Theodore Roosevelt expedition to Africa in late 1800s
# An exception occurred
# edanmdm-nmah_807480 Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_514001 Impressions of Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_816854 Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_534224 "McKinley/ Theodore Roosevelt"
# An exception occurred
# edanmdm-nmah_534193 "For Governor Theodore Roosevelt"
# An exception occurred
# edanmdm-npm_0.242263.3171 30c Theodore Roosevelt plate proof
# NPM-0_242263_3171
# edanmdm-nmah_1760391 Campaign Button, Theodore Roosevelt, 1904
# An exception occurred
# edanmdm-nmnhbotany_12906342 Dimelaena oreina (Ach.) Norm.
# An exception occurred
# edanmdm-nmnhbotany_2635782 Xanthoparmelia taractica (Kremp.) Hale
# An exception occurred
# edanmdm-nmnhbotany_2851411 Rumex verticillatus L.
# ark:/65665/m3a69688294e0e4958896bd478dce861f7
# edanmdm-chndm_1982-52-6 Theodore Roosevelt
# CHSDM-D30754D8E1512-000001
# edanmdm-siris_sil_903679 African game trails : an account of the African wanderings of an American hunter-naturalist / by Theodore Roosevelt ; illustrations from photographs by Kermit Roosevelt and other members of the expedition. [Pt.] I-XII
# An exception occurred
# edanmdm-siris_sil_243078 The deer family, by Theodore Roosevelt, T.S. Van Dyke, D.G. Elliot and A.J. Stone; illustrated byCarl Rungius and others
# An exception occurred
# edanmdm-nmah_529371 Buckle, Theodore Roosevelt, 1904
# An exception occurred
# edanmdm-nmah_501817 Pin, Theodore Roosevelt
# An exception occurred
# edanmdm-siris_sil_211115 African game trails, an account of the African wanderings of an American hunter-naturalist, by Theodore Roosevelt. Illustrations from photographs by Kermit Roosevelt and other members of the expedition. [Pt.] I-XII
# An exception occurred
# edanmdm-nmah_513977 How Theodore Roosevelt Became President of the United States
# An exception occurred
# edanmdm-nmah_682982 Voices From the Past: Theodore Roosevelt - The Square Deal
# An exception occurred
# edanmdm-nmah_1186699 Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_1186379 Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_1855928 President Theodore Roosevelt (?)
# An exception occurred
# edanmdm-nmah_1452477 Theodore Roosevelt [Bradley Company coal advertisement]
# An exception occurred
# edanmdm-nmah_520838 Theodore Roosevelt, Address ...
# An exception occurred
# edanmdm-nmah_525854 Theodore Roosevelt
# An exception occurred
# edanmdm-siris_sil_113476 American big-game hunting: the book of the Boone and Crockett club; editors, Theodore Roosevelt, George Bird Grinnell
# An exception occurred
# edanmdm-siris_sil_23258 Theodore Roosevelt, the citizen, by Jacob A. Riis ..
# An exception occurred
# edanmdm-nmah_960223 Theodore Roosevelt Inauguration medal, United States, 1905
# An exception occurred
# edanmdm-nmah_514037 penholder
# An exception occurred
# edanmdm-nmah_514038 pen rack
# An exception occurred
# edanmdm-nmah_514039 penholder
# An exception occurred
# edanmdm-saam_2014.29.3 Theodore Roosevelt U.S. Mint Presidential Medal
# SAAM-2014.29.3_1
# edanmdm-saam_1955.9.3 Theodore Roosevelt
# SAAM-1955.9.3_1
# edanmdm-siris_sil_976324 Theodore Roosevelt letter to Elliott L. Coues, 1882 Apr. 21
# An exception occurred
# edanmdm-nmah_1829975 Campain Pin, Theodore Roosevelt
# An exception occurred
# edanmdm-nmah_491853 Pin, Theodore Roosevelt, 1904
# An exception occurred
# edanmdm-nmah_1382286 Theodore Roosevelt Commemorative Token
# An exception occurred
# edanmdm-nmah_1382683 Theodore Roosevelt Commemorative Token
# An exception occurred
# edanmdm-nmah_1382682 Theodore Roosevelt Commemorative Token
# An exception occurred
# edanmdm-nmah_513982 Mr Roosevelt and the Presidency
# An exception occurred
# edanmdm-nmah_515513 piano bench
# An exception occurred
# edanmdm-nmah_515514 piano
# An exception occurred
# edanmdm-siris_sil_629625 African game trails : an account of the African wanderings of an American hunter-naturalist / by Theodore Roosevelt ; new introduction by H.W. Brands ; with more than two hundred illustrations from photographs by Kermit Roosevelt and other members of the expedition and from drawings by Philip R. Goodwin
# An exception occurred

# %% [markdown]
# # Create some summary data
#
# We can use Pandas to give us a quick overview of the dataset.

# %%
# Load the CSV file from GitHub.
# This puts the data in a Pandas DataFrame
df = pd.read_csv('si_records.csv')

# %% [markdown]
# ## Have a peek

# %%
df
# Out:
#                                                 title          date  \
# 0                                  Theodore Roosevelt       c. 1905
# 1                                  Theodore Roosevelt  Sept 4, 1902
# 2                                  Theodore Roosevelt          1884
# 3                                  Theodore Roosevelt          1905
# 4                                  Theodore Roosevelt       c. 1905
# 5                                  Theodore Roosevelt          1904
# 6                                  Theodore Roosevelt          1907
# 7                                  Theodore Roosevelt          1905
# 8                                  Theodore Roosevelt       c. 1903
# 9                                  Theodore Roosevelt       c. 1915
# 10                                 Theodore Roosevelt       c. 1905
# 11                                 Theodore Roosevelt          1905
# 12              Theodore Roosevelt and Frank J. Hogan       c. 1905
# 13                                 His Master's Voice          1912
# 14            Teddy Roosevelt and Oscar Edward Cesare       c. 1916
# 15            Theodore Roosevelt and Albert Beveridge       c. 1912
# 16                                 Theodore Roosevelt       c. 1898
# 17                                 Theodore Roosevelt          1906
# 18                                 Theodore Roosevelt          1904
# 19                                 Theodore Roosevelt          1904
# 20                                 Theodore Roosevelt          1909
# 21                                 Theodore Roosevelt       c. 1905
# 22                                 Theodore Roosevelt   Apr 1, 1907
# 23                                 Theodore Roosevelt          1905
# 24  Theodore Roosevelt, John Milton Hay, Joseph Gu...       c. 1905
# 25                                 Theodore Roosevelt          1904
# 26                                 Theodore Roosevelt          1904
# 27                                 Theodore Roosevelt          1904
# 28                              Made Harmless at Last          1884
# 29                                 Theodore Roosevelt          1915
# 30                                 Theodore Roosevelt          1915
#
#    media_usage                data_source  \
# 0          CC0  National Portrait Gallery
# 1          CC0  National Portrait Gallery
# 2          CC0  National Portrait Gallery
# 3          CC0  National Portrait Gallery
# 4          CC0  National Portrait Gallery
# 5          CC0  National Portrait Gallery
# 6          CC0  National Portrait Gallery
# 7          CC0  National Portrait Gallery
# 8          CC0  National Portrait Gallery
# 9          CC0  National Portrait Gallery
# 10         CC0  National Portrait Gallery
# 11         CC0  National Portrait Gallery
# 12         CC0  National Portrait Gallery
# 13         CC0  National Portrait Gallery
# 14         CC0  National Portrait Gallery
# 15         CC0  National Portrait Gallery
# 16         CC0  National Portrait Gallery
# 17         CC0  National Portrait Gallery
# 18         CC0  National Portrait Gallery
# 19         CC0  National Portrait Gallery
# 20         CC0  National Portrait Gallery
# 21         CC0  National Portrait Gallery
# 22         CC0  National Portrait Gallery
# 23         CC0  National Portrait Gallery
# 24         CC0  National Portrait Gallery
# 25         CC0  National Portrait Gallery
# 26         CC0  National Portrait Gallery
# 27         CC0  National Portrait Gallery
# 28         CC0  National Portrait Gallery
# 29         CC0  National Portrait Gallery
# 30         CC0  National Portrait Gallery
#
#                                            dimensions  \
# 0       45.6cm x 30.6cm (17 15/16" x 12 1/16"), Image
# 1                   Mat: 56 × 40.7 cm (22 1/16 × 16")
# 2             15cm x 10.6cm (5 7/8" x 4 3/16"), Image
# 3                                                 NaN
# 4                      Mat: 45.7 × 35.6 cm (18 × 14")
# 5         14.5cm x 18.9cm (5 11/16" x 7 7/16"), Image
# 6           25.1cm x 20.5cm (9 7/8" x 8 1/16"), Image
# 7          Sheet: 61.2 x 45.5 cm (24 1/8 x 17 15/16")
# 8             Sheet: 63.5cm x 41.7cm (25" x 16 7/16")
# 9                Sheet: 45.7 × 35.3 cm (18 × 13 7/8")
# 10       Sheet: 56.6 x 38.0 cm. (22 1/16 X 14 15/16")
# 11           Sheet: 29.7 x 22.5cm (11 11/16 x 8 7/8")
# 12          22.2cm x 34.3cm (8 3/4" x 13 1/2"), Image
# 13          Sheet: 38 x 27.5cm (14 15/16 x 10 13/16")
# 14        Sheet: 58.5cm x 37.1cm (23 1/16" x 14 5/8")
# 15           19cm x 25.8cm (7 1/2" x 10 3/16"), Image
# 16          Mat: 71.1 x 55.9 x 0.6cm (28 x 22 x 1/4")
# 17                      Mat: 55.9 x 40.6cm (22 x 16")
# 18           13.6cm x 8.1cm (5 3/8" x 3 3/16"), Image
# 19             7.8cm x 13cm (3 1/16" x 5 1/8"), Image
# 20     40.1cm x 50.6cm (15 13/16" x 19 15/16"), Image
# 21      Mount: 27.4cm x 25.6cm (10 13/16" x 10 1/16")
# 22  Book closed: 31.5 × 24.5 × 2.7 cm (12 3/8 × 9 ...
# 23       25.3cm x 20.2cm (9 15/16" x 7 15/16"), Image
# 24           Image/Sheet: 28 × 75.5 cm (11 × 29 3/4")
# 25         13.1cm x 7.5cm (5 3/16" x 2 15/16"), Image
# 26           13.6cm x 8.1cm (5 3/8" x 3 3/16"), Image
# 27          18.2cm x 23.1cm (7 3/16" x 9 1/8"), Image
# 28        Sheet: 33.7cm x 25.8cm (13 1/4" x 10 3/16")
# 29          Mount: 45 x 32.6cm (17 11/16 x 12 13/16")
# 30          Mount: 45 x 32.6cm (17 11/16 x 12 13/16")
#
#                                                sitter        type  \
# 0        Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 1        Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919       Print
# 2        Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 3        Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 4        Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 5        Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 6        Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 7        Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919       Print
# 8        Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919       Print
# 9        Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919       Print
# 10       Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919       Print
# 11       Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919       Print
# 12                        Frank J. Hogan, 1877 - 1944  Photograph
# 13       Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919       Print
# 14       Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919     Drawing
# 15             Albert Jeremiah Beveridge, 1862 - 1927  Photograph
# 16       Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 17       Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 18  Edith Kermit Carow Roosevelt, 6 Aug 1861 - 30 ...  Photograph
# 19  Edith Kermit Carow Roosevelt, 6 Aug 1861 - 30 ...  Photograph
# 20       Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 21       Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 22       Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 23       Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 24     Joseph Gurney Cannon, 7 May 1836 - 12 Nov 1926     Drawing
# 25       Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 26       Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 27       Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 28  Stephen Grover Cleveland, 18 Mar 1837 - 24 Jun...       Print
# 29       Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
# 30       Theodore Roosevelt, 27 Oct 1858 - 6 Jan 1919  Photograph
#
#                                           medium  \
# 0                                   Photogravure
# 1                      Chromolithograph on paper
# 2                           Albumen silver print
# 3                           Gelatin silver print
# 4                           Gelatin silver print
# 5                           Gelatin silver print
# 6                           Gelatin silver print
# 7                               Etching on paper
# 8                               Etching on paper
# 9                               Etching on paper
# 10                           Lithograph on paper
# 11                              Etching on paper
# 12                          Gelatin silver print
# 13         Hand-colored photolithograph on paper
# 14  India ink, Chinese white and pencil on paper
# 15                          Gelatin silver print
# 16                                Platinum print
# 17                          Gelatin silver print
# 18                          Gelatin silver print
# 19                          Gelatin silver print
# 20                          Gelatin silver print
# 21                          Gelatin silver print
# 22                                  Photogravure
# 23                          Gelatin silver print
# 24                                 Ink & whitner
# 25                          Gelatin silver print
# 26                          Gelatin silver print
# 27                          Gelatin silver print
# 28                     Chromolithograph on paper
# 29                                  Photogravure
# 30                                  Photogravure
#
#                                                artist  \
# 0                        Pirie MacDonald, 1867 - 1942
# 1   Vincent, Brooks, Day & Son Lithography Company...
# 2                        Julius Ludovici, active 1884
# 3        Underwood & Underwood, active 1880 - c. 1950
# 4                                 Unidentified Artist
# 5             Jessie Tarbox Beals, 1870 - 30 May 1942
# 6           Harris & Ewing Studio, active 1905 - 1977
# 7                    Sidney Lawton Smith, 1845 - 1929
# 8                       Albert Rosenthal, 1863 - 1939
# 9                          James S. King, 1852 - 1925
# 10                         Leo Mielziner, 1869 - 1935
# 11            Anders Leonard Zorn, 18 Feb 1860 - 1920
# 12          Harris & Ewing Studio, active 1905 - 1977
# 13                 Walter Joseph Enright, 1879 - 1969
# 14                   Oscar Edward Cesare, 1885 - 1948
# 15                                Unidentified Artist
# 16           Pach Brothers Studio, active 1867 - 1993
# 17       Underwood & Underwood, active 1880 - c. 1950
# 18            Jessie Tarbox Beals, 1870 - 30 May 1942
# 19            Jessie Tarbox Beals, 1870 - 30 May 1942
# 20        Barnett McPhee Clinedinst, Jr., 1862 - 1953
# 21       Underwood & Underwood, active 1880 - c. 1950
# 22    Alvin Langdon Coburn, 11 Jun 1882 - 23 Nov 1966
# 23       Underwood & Underwood, active 1880 - c. 1950
# 24                Charles Davis Mitchell, 1887 - 1940
# 25            Jessie Tarbox Beals, 1870 - 30 May 1942
# 26            Jessie Tarbox Beals, 1870 - 30 May 1942
# 27            Jessie Tarbox Beals, 1870 - 30 May 1942
# 28                Frederich Graetz, c. 1840 - c. 1913
# 29                       Pirie MacDonald, 1867 - 1942
# 30                       Pirie MacDonald, 1867 - 1942
#
#                                                 link
# 0   https://ids.si.edu/ids/manifest/NPG-S-NPG_77_223
# 1      https://ids.si.edu/ids/manifest/NPG-NPG_81_53
# 2     https://ids.si.edu/ids/manifest/NPG-NPG_81_125
# 3     https://ids.si.edu/ids/manifest/NPG-NPG_81_163
# 4    https://ids.si.edu/ids/manifest/NPG-S-NPG_77_41
# 5     https://ids.si.edu/ids/manifest/NPG-NPG_81_131
# 6   https://ids.si.edu/ids/manifest/NPG-S-NPG_84_285
# 7     https://ids.si.edu/ids/manifest/NPG-8000114B_1
# 8      https://ids.si.edu/ids/manifest/NPG-NPG_91_21
# 9     https://ids.si.edu/ids/manifest/NPG-NPG_97_198
# 10     https://ids.si.edu/ids/manifest/NPG-NPG_99_32
# 11   https://ids.si.edu/ids/manifest/NPG-A4000016B_1
# 12  https://ids.si.edu/ids/manifest/NPG-S-NPG_84_296
# 13   https://ids.si.edu/ids/manifest/NPG-AD-NPG_78_4
# 14     https://ids.si.edu/ids/manifest/NPG-NPG_92_95
# 15      https://ids.si.edu/ids/manifest/NPG-8110070C
# 16    https://ids.si.edu/ids/manifest/NPG-8100242C_2
# 17    https://ids.si.edu/ids/manifest/NPG-NPG_81_127
# 18    https://ids.si.edu/ids/manifest/NPG-NPG_81_132
# 19    https://ids.si.edu/ids/manifest/NPG-NPG_81_135
# 20    https://ids.si.edu/ids/manifest/NPG-NPG_81_171
# 21  https://ids.si.edu/ids/manifest/NPG-S-NPG_91_214
# 22  https://ids.si.edu/ids/manifest/NPG-NPG_87_288_n
# 23    https://ids.si.edu/ids/manifest/NPG-NPG_81_124
# 24   https://ids.si.edu/ids/manifest/NPG-S-NPG_80_19
# 25    https://ids.si.edu/ids/manifest/NPG-NPG_81_133
# 26    https://ids.si.edu/ids/manifest/NPG-NPG_81_134
# 27    https://ids.si.edu/ids/manifest/NPG-NPG_81_130
# 28    https://ids.si.edu/ids/manifest/NPG-NPG_96_116
# 29   https://ids.si.edu/ids/manifest/NPG-A2000852C_1
# 30   https://ids.si.edu/ids/manifest/NPG-A2000852C_2

# %% [markdown]
# ## How many items?

# %%
# How many items?
len(df)

# %% [markdown]
# ## Exploring the authors

# %%
# Get unique values
artist = pd.unique(df['artist'].str.split('|', expand=True).stack()).tolist()
for a in sorted(artist):
    print(a)

# %% [markdown]
# ## How often is each name used?

# %%
# Splits the people column and counts frequencies
artist_counts = df['artist'].str.split('|').apply(lambda x: pd.Series(x).value_counts()).sum().astype('int').sort_values(ascending=False).to_frame().reset_index(level=0)
# Add column names
artist_counts.columns = ['name', 'count']
# Display with horizontal bars
display(artist_counts.style.bar(subset=['count'], color='#d65f5f').set_properties(subset=['count'], **{'width': '300px'}))

# %% [markdown]
# ## Creating a list of unique types

# %%
# Get unique values
types = pd.unique(df['type']).tolist()
for type in sorted(types, key=str.lower):
    print(type)

# %% [markdown]
# ## Face detection with OpenCV
# Face detection is a computer vision technology that locates human faces in digital images and videos. Let's try to identify.
#
# Open Source Computer Vision Library\cite{opencv} (OpenCV) is an open source computer vision and machine learning software library. In this example, images are treated as an standard Numpy array containing pixels of data points.

# %% [markdown]
# Read in the image using the imread function. We will be using the colored 'mandrill' image for demonstration purpose.

# %%
test_image = cv2.imread('smithsonian-example.jpg')

plt.imshow(test_image)

# %% [markdown]
# The type and shape of the array.

# %%
print(type(test_image))
print(test_image.shape)

# %% [markdown]
# Regarding the color, we expected a bright colored image but we obtained a bluish image. That happens because OpenCV and matplotlib have different orders of primary colors
#
# While OpenCV reads images using BGR, matplotlib uses RGB. To avoid this issue, we will transform how matplotlib expects it using a cvtColor function.

# %%
rgb_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image)

# %%
#We define a function
def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ## Haar cascade files
# OpenCV comes with a lot of pre-trained classifiers. For instance, there are classifiers for smile, eyes, face, etc.
#
# ### Loading the classifier for frontal face

# %%
haar_cascade_face = cv2.CascadeClassifier('opencv/haarcascade_frontalface_default.xml')

# %% [markdown]
# ## Face detection
# We shall be using the detectMultiscale module of the classifier. This function will return a rectangle with coordinates(x,y,w,h) around the detected face.

# %%
faces_rects = haar_cascade_face.detectMultiScale(test_image, scaleFactor = 1.2, minNeighbors = 5);

# Let us print the no. of faces found
print('Faces found: ', len(faces_rects))

# %% [markdown]
# Our next step is to loop over all the coordinates it returned and draw rectangles around them using Open CV. We will be drawing a green rectangle with a thickness of 2

# %%
for (x,y,w,h) in faces_rects:
     cv2.rectangle(test_image, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %% [markdown]
# Finally, we display the original image to identify if the face has been detected correctly.

# %%
plt.imshow(convertToRGB(test_image))

# %% [markdown]
# ## Let's do face detection for all the images
#
# First we download all the portraits

# %%
for index, row in df.iterrows():
    print(index, row['imageUrl'])
    response = requests.get(row['imageUrl'])
    img = Image.open(BytesIO(response.content))
    img.save('is-images/m-{}.jpg'.format(row['id']), quality=90)

# %% [markdown]
# And we process them in a loop

# %%
rows = 20
files = os.listdir('is-images')

fig = plt.figure(figsize=(100,300))
for num, x in enumerate(files):
    #img = Image.open('is-images/'+ x)
    img = cv2.imread('is-images/'+ x)
    
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces_rects = haar_cascade_face.detectMultiScale(img_gray, scaleFactor = 1.2, minNeighbors = 5);      
    
    for (x,y,w,h) in faces_rects:
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
        
    #convert image to RGB and show image
    img_face = convertToRGB(img)    
    
    plt.subplot(rows,5,num+1)
    plt.axis('off')
    plt.imshow(img_face)

# %% [markdown]
# ## References
# https://www.datacamp.com/community/tutorials/face-detection-python-opencv
