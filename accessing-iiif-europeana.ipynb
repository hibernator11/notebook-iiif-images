# %% [markdown]
# # Accessing Europeana IIIF APIs
# [Europeana IIIF APIs](https://pro.europeana.eu/page/iiif), allows us to download, share, and reuse images and text of Europeana newspapers.
#
# This notebook tries to introduce how to explore the repository, basically search, read a record, obtain the fulltext and create a CSV dataset.
#
# Europeana IIIF APIs requires an API key to access the endpoints. Please register with https://pro.europeana.eu/page/get-api to get a key.

# %% [markdown]
# ## Setting up things

# %%
import requests, csv
import json
import pandas as pd

# %% [markdown]
# ## Glogal configuration
# In this section, we can add our api_key, the text that we want to use to search and retrieve the elements, and the number of records to retrieve.

# %%
api_key = 'J6W44jvPV'
query = 'paris'

# %% [markdown]
# ## Performing a search using the API
# The API allows us searching on text and retrieving the hits highlighted, as traditional systems (e.g. Lucene and Solr).

# %%
#url = 'https://newspapers.eanadev.org/api/v2/search.json?query=paris&profile=hits&wskey=J6W44jvPV'
url = 'https://newspapers.eanadev.org/api/v2/search.json'
r = requests.get(url, params = {'query': query, 'profile': 'hits', 'wskey': api_key })
print(r.url)
response = r.text
print(response)
# Out:
# https://newspapers.eanadev.org/api/v2/search.json?query=paris&profile=hits&wskey=J6W44jvPV
# {"apikey":"J6W44jvPV","success":true,"requestNumber":999,"itemsCount":12,"totalResults":439085,"items":[{"completeness":5,"country":["Latvia"],"dataProvider":["National Library of Latvia"],"dcLanguage":["lv","ru"],"dcLanguageLangAware":{"def":["lv","ru"]},"dcTitleLangAware":{"def":["Sarkanais Sports - 1941-03-10"]},"edmConcept":["http://data.europeana.eu/concept/base/18"],"edmConceptLabel":[{"def":"Zeitung"},{"def":"Avis"},{"def":"Газета"},{"def":"Газета"},{"def":"Sanomalehti"},{"def":"Jornal"},{"def":"Вестник"},{"def":"Laikraštis"},{"def":"Laikraksts"},{"def":"Novine"},{"def":"Journal"},{"def":"Újság"},{"def":"Լրագիր"},{"def":"Novine"},{"def":"Газета"},{"def":"გაზეთი"},{"def":"Denník (žurnalistika)"},{"def":"Časopis"},{"def":"Nuachtán"},{"def":"Pàipear-naidheachd"},{"def":"Gazeta"},{"def":"Весник"},{"def":"Premsa"},{"def":"Новине"},{"def":"Tidning"},{"def":"신문"},{"def":"Prensa escrita"},{"def":"Εφημερίδα"},{"def":"Newspaper"},{"def":"Dagblað"},{"def":"Giornale"},{"def":"Prensa escrita"},{"def":"報紙"},{"def":"Ajaleht"},{"def":"Noviny"},{"def":"Egunkari"},{"def":"صحيفة"},{"def":"Papur newydd"},{"def":"新聞"},{"def":"Qəzet"},{"def":"Gazeta"},{"def":"עיתון"},{"def":"Avis"},{"def":"Ziar"},{"def":"Krant"},{"def":"Gazete"}],"edmConceptPrefLabelLangAware":{"de":["Zeitung"],"no":["Avis"],"ru":["Газета"],"be":["Газета"],"fi":["Sanomalehti"],"pt":["Jornal"],"bg":["Вестник"],"lt":["Laikraštis"],"lv":["Laikraksts"],"hr":["Novine"],"fr":["Journal"],"hu":["Újság"],"hy":["Լրագիր"],"bs":["Novine"],"uk":["Газета"],"ka":["გაზეთი"],"sk":["Denník (žurnalistika)"],"sl":["Časopis"],"ga":["Nuachtán"],"gd":["Pàipear-naidheachd"],"sq":["Gazeta"],"mk":["Весник"],"ca":["Premsa"],"sr":["Новине"],"sv":["Tidning"],"ko":["신문"],"gl":["Prensa escrita"],"el":["Εφημερίδα"],"en":["Newspaper"],"is":["Dagblað"],"it":["Giornale"],"es":["Prensa escrita"],"zh":["報紙"],"et":["Ajaleht"],"cs":["Noviny"],"eu":["Egunkari"],"ar":["صحيفة"],"cy":["Papur newydd"],"ja":["新聞"],"az":["Qəzet"],"pl":["Gazeta"],"he":["עיתון"],"da":["Avis"],"ro":["Ziar"],"nl":["Krant"],"tr":["Gazete"]},"edmDatasetName":["9200303_Ag_EU_TEL_a0617_Newspapers_Latvia"],"edmIsShownBy":["https://iiif.europeana.eu/image/J4YXS64E2WAE74GYN5F7KGYD676H5B4GXZOKGCUKVEKNHMF7NWGQ/presentation_images/01121280-0211-11e6-b68d-fa163e60dd72/node-1/image/NLL/Sarkanais_Sports/1941/03/10/p_001_sasp1941n029_001/full/full/0/default.jpg"],"edmPreview":["https://europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2FJ4YXS64E2WAE74GYN5F7KGYD676H5B4GXZOKGCUKVEKNHMF7NWGQ%2Fpresentation_images%2F01121280-0211-11e6-b68d-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FSarkanais_Sports%2F1941%2F03%2F10%2Fp_001_sasp1941n029_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT"],"europeanaCollectionName":["9200303_Ag_EU_TEL_a0617_Newspapers_Latvia"],"europeanaCompleteness":5,"guid":"https://www.europeana.eu/item/9200303/BibliographicResource_3000059897587?utm_source=api&utm_medium=api&utm_campaign=J6W44jvPV","id":"/9200303/BibliographicResource_3000059897587","index":0,"language":["lv"],"link":"https://europeana.eu/api/v2/record/9200303/BibliographicResource_3000059897587.json?wskey=J6W44jvPV","previewNoDistribute":false,"provider":["The European Library"],"rights":["http://creativecommons.org/publicdomain/mark/1.0/"],"score":8.363002,"timestamp":1539143571558,"timestamp_created":"2014-05-01T14:41:27.388Z","timestamp_created_epoch":1398955287388,"timestamp_update":"2018-06-25T09:03:07.172Z","timestamp_update_epoch":1529917387172,"title":["Sarkanais Sports - 1941-03-10"],"type":"TEXT","ugc":[false]},{"completeness":5,"country":["Latvia"],"dataProvider":["National Library of Latvia"],"dcLanguage":["lv","ru"],"dcLanguageLangAware":{"def":["lv","ru"]},"dcTitleLangAware":{"def":["Sarkanais Sports - 1941-04-14"]},"edmConcept":["http://data.europeana.eu/concept/base/18"],"edmConceptLabel":[{"def":"Zeitung"},{"def":"Avis"},{"def":"Газета"},{"def":"Газета"},{"def":"Sanomalehti"},{"def":"Jornal"},{"def":"Вестник"},{"def":"Laikraštis" ...

# %% [markdown]
# ## Displaying the mentions in the transcribed text where the search keyword was found.

# %%
results = json.loads(response)

for r in results['hits']:
    print('id:' + r['scope'])
    for s in r['selectors']:
        
        print(s.get('prefix', '') + s.get('exact', '') + s.get('suffix', ''))
# Out:
# id:/9200303/BibliographicResource_3000059897585
# Latvijas PSR meistars Bērziņš skrēja vienā pāri ar Tomskas ātrslidotāju Sergēju.
# id:/9200303/BibliographicResource_3000059897596
# Eiropas čempions Alfonss Bērziņš skrēja vienā pāri ar Saburovu (Ļeņlngrada).
# id:/9200303/BibliographicResource_3000059897574
# Toto: vk 18.—, it 29,—, pāris 266.—. Hanovera Diloņa lieliskā uzvara.
# id:/9200303/BibliographicResource_3000059897894
# Ei»er dieser Streiche ist berühmt gewolden und wurde in früheren Jahren oft erzählt: Der Thier-inaler Jadin hatte einen Freund, der im Jardin des Plantes (der zoologische Garten in Paris) Beamter war; diesen Freund bat er, ihm für eine Opern 11 acht eine» seiner Bären, den in ganz
# id:/9200303/BibliographicResource_3000059897564
# Toto: vk par Janošu 10.—, it par Žubīti 32.—, pāris 53.50. 3. 1. Klaips — J.
# id:/9200303/BibliographicResource_3000059897584
# No teicamas si tuācijas pāri lietuviešu vārtiem pārlidoja Uukkivi raidījums.
# id:/9200303/BibliographicResource_3000059897600
# Darba praksē ļoti bieži izskaidrojuma vietā lieto vingrinājuma apraksta Maz pieredzē jis skolotājs, izskaidrodams lēcienu žākļu stā jā pāri vingrošanas zirgam, saka: «Kad lēcat zirgam
# id:/9200303/BibliographicResource_3000059897557
# Visā sacīkstes laikā ne mitīgi vietām, maini jās abi pāri, bet finišos allaž uzvarētāji palika ASK vīri.
# id:/9200303/BibliographicResource_3000059897587
# Lēcieni balstā: pāri zirgam sānis,
# id:/9200303/BibliographicResource_3000059897599
# Pēdējie galu galā bija pirmie: ātrākie sacensoņi skrēja tieši pēdējā pāri.
# id:/9200303/BibliographicResource_3000059897603
# Pāri laukuma vidum, novelk tenisa tīklu, un baltā bumbiņa raiti lido tur, kur parasti re dzam basketbolistu cīņas.
# id:/9200303/BibliographicResource_3000059897618
# Tur Tabaks slidoja pēdējā pārī,
# [kad ledus bija jau stipri izbraukts.

# %% [markdown]
# ## Creating a CSV file

# %%
csv_out = csv.writer(open('eu_records.csv', 'w'), delimiter = ',', quotechar = '"', quoting = csv.QUOTE_MINIMAL)
csv_out.writerow(['title', 'thumbnail', 'date', 'license', 'typem', 'language', 'fulltextUrl', 'manifestUrl', 'fulltext'])
# Out:
# 78

# %% [markdown]
# ## Retrieving the manifests
# A manifest describes the information needed for a viewer to present a digital object to the user, such as the title and the sequence of views/images. We can also retrieve the manifest of each item. According to the Europeana documentation, the request follows the pattern https://iiif.europeana.eu/presentation/[RECORD_ID]/manifest
#
# The manifest includes the metadata, some of the attribues are multivalued.
#
# The full text is available at
# https://www.europeana.eu/api/fulltext/9200303/BibliographicResource_3000059898023/472ef0641de5cce2ba8eb26d67110ed6#char=0,10o

# %%
results = json.loads(response)

for r in results['hits']:
    
    title = thumbnail = date = license = typem = language = fulltextUrl = manifestUrl = fulltext =''
    
    manifestUrl = 'https://iiif.europeana.eu/presentation/' + r['scope'] + '/manifest'
    responseManifest = requests.get(manifestUrl, params = {'wskey': api_key })
    print(responseManifest.url)
    
    # retrieving the metadata
    m = json.loads(responseManifest.text)
    
    # retrieving metadata
    title = m['label'][0]['@value']
    thumbnail = m['thumbnail']['@id']
    date = m['navDate']
    license = m['license']

    for i in m['metadata']:
        if i['label'] == 'type':
            typem = i['value'][0]['@value']
        elif i['label'] == 'language':
            language = i['value'][0]['@value']
        else: pass
        
    ## getting the full text
    annopageUrl = 'https://iiif.europeana.eu/presentation/' + r['scope'] + '/annopage/1'
    responseAnnopage = requests.get(annopageUrl, params = {'wskey': api_key })
    print(responseAnnopage.url)
    
    a = json.loads(responseAnnopage.text)
    fulltextUrl = a['resources'][0]['resource']['@id']
    print(fulltextUrl)
    
    responseFulltext = requests.get(fulltextUrl, params = {'wskey': api_key })
   
    # retrieving the metadata
    f = json.loads(responseFulltext.text)
    # TODO check encoding
    fulltext = f['value']
   
    print('-------')
    
    csv_out.writerow([title, thumbnail, date, license, typem, language, fulltextUrl, manifestUrl, fulltext])
# Out:
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897585/manifest?wskey=J6W44jvPV
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897585/annopage/1?wskey=J6W44jvPV
# https://www.europeana.eu/api/fulltext/9200303/BibliographicResource_3000059897585/47cfd10478e1981f348ccabf9fd2de3e
# -------
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897596/manifest?wskey=J6W44jvPV
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897596/annopage/1?wskey=J6W44jvPV
# https://www.europeana.eu/api/fulltext/9200303/BibliographicResource_3000059897596/33ac018d7d9d0d5442e0214c3f3f13d1
# -------
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897574/manifest?wskey=J6W44jvPV
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897574/annopage/1?wskey=J6W44jvPV
# https://www.europeana.eu/api/fulltext/9200303/BibliographicResource_3000059897574/50d44c2664acda1836218698fb2f7165
# -------
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897894/manifest?wskey=J6W44jvPV
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897894/annopage/1?wskey=J6W44jvPV
# https://www.europeana.eu/api/fulltext/9200303/BibliographicResource_3000059897894/5f5b8744d6f2e5deda35b2eec18018ad
# -------
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897564/manifest?wskey=J6W44jvPV
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897564/annopage/1?wskey=J6W44jvPV
# https://www.europeana.eu/api/fulltext/9200303/BibliographicResource_3000059897564/15e243b3e4da2a963a085c72eae27d16
# -------
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897584/manifest?wskey=J6W44jvPV
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897584/annopage/1?wskey=J6W44jvPV
# https://www.europeana.eu/api/fulltext/9200303/BibliographicResource_3000059897584/1c3fc41419a5aec2f11755cfc0c09aea
# -------
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897600/manifest?wskey=J6W44jvPV
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897600/annopage/1?wskey=J6W44jvPV
# https://www.europeana.eu/api/fulltext/9200303/BibliographicResource_3000059897600/8e26c6bd71e8c4447c9e4b56f45c4855
# -------
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897557/manifest?wskey=J6W44jvPV
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897557/annopage/1?wskey=J6W44jvPV
# https://www.europeana.eu/api/fulltext/9200303/BibliographicResource_3000059897557/a47168ebec4642a61c520640306a9ab9
# -------
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897587/manifest?wskey=J6W44jvPV
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897587/annopage/1?wskey=J6W44jvPV
# https://www.europeana.eu/api/fulltext/9200303/BibliographicResource_3000059897587/e96cd1cf8af21ea9ac2dd65a79c2c190
# -------
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897599/manifest?wskey=J6W44jvPV
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897599/annopage/1?wskey=J6W44jvPV
# https://www.europeana.eu/api/fulltext/9200303/BibliographicResource_3000059897599/4c27224c9c15103f32952242ed19fd15
# -------
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897603/manifest?wskey=J6W44jvPV
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897603/annopage/1?wskey=J6W44jvPV
# https://www.europeana.eu/api/fulltext/9200303/BibliographicResource_3000059897603/76724a3d9be199ceccee173f5b518eff
# -------
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897618/manifest?wskey=J6W44jvPV
# https://iiif.europeana.eu/presentation//9200303/BibliographicResource_3000059897618/annopage/1?wskey=J6W44jvPV
# https://www.europeana.eu/api/fulltext/9200303/BibliographicResource_3000059897618/a6780846f90ee43082f3eb5eeb7e2f5d
# -------

# %%
# Load the CSV file from GitHub.
# This puts the data in a Pandas DataFrame
df = pd.read_csv('eu_records.csv')

# %% [markdown]
# ## Have a peek

# %%
df
# Out:
#                               title  \
# 0     Sarkanais Sports - 1941-02-17
# 1     Sarkanais Sports - 1941-01-27
# 2     Sarkanais Sports - 1940-10-07
# 3   Windausche Zeitung - 1903-11-14
# 4     Sarkanais Sports - 1940-12-30
# 5     Sarkanais Sports - 1940-09-09
# 6     Sarkanais Sports - 1941-04-07
# 7     Sarkanais Sports - 1940-08-19
# 8     Sarkanais Sports - 1941-03-10
# 9     Sarkanais Sports - 1941-01-20
# 10    Sarkanais Sports - 1941-04-14
# 11    Sarkanais Sports - 1941-02-24
# 12    Sarkanais Sports - 1941-02-17
# 13    Sarkanais Sports - 1941-01-27
# 14    Sarkanais Sports - 1940-10-07
# 15  Windausche Zeitung - 1903-11-14
# 16    Sarkanais Sports - 1940-12-30
# 17    Sarkanais Sports - 1940-09-09
# 18    Sarkanais Sports - 1941-04-07
# 19    Sarkanais Sports - 1940-08-19
# 20    Sarkanais Sports - 1941-03-10
# 21    Sarkanais Sports - 1941-01-20
# 22    Sarkanais Sports - 1941-04-14
# 23    Sarkanais Sports - 1941-02-24
#
#                                             thumbnail                  date  \
# 0   https://api.europeana.eu/api/v2/thumbnail-by-u...  1941-02-17T00:00:00Z
# 1   https://api.europeana.eu/api/v2/thumbnail-by-u...  1941-01-27T00:00:00Z
# 2   https://api.europeana.eu/api/v2/thumbnail-by-u...  1940-10-07T00:00:00Z
# 3   https://api.europeana.eu/api/v2/thumbnail-by-u...  1903-11-14T00:00:00Z
# 4   https://api.europeana.eu/api/v2/thumbnail-by-u...  1940-12-30T00:00:00Z
# 5   https://api.europeana.eu/api/v2/thumbnail-by-u...  1940-09-09T00:00:00Z
# 6   https://api.europeana.eu/api/v2/thumbnail-by-u...  1941-04-07T00:00:00Z
# 7   https://api.europeana.eu/api/v2/thumbnail-by-u...  1940-08-19T00:00:00Z
# 8   https://api.europeana.eu/api/v2/thumbnail-by-u...  1941-03-10T00:00:00Z
# 9   https://api.europeana.eu/api/v2/thumbnail-by-u...  1941-01-20T00:00:00Z
# 10  https://api.europeana.eu/api/v2/thumbnail-by-u...  1941-04-14T00:00:00Z
# 11  https://api.europeana.eu/api/v2/thumbnail-by-u...  1941-02-24T00:00:00Z
# 12  https://api.europeana.eu/api/v2/thumbnail-by-u...  1941-02-17T00:00:00Z
# 13  https://api.europeana.eu/api/v2/thumbnail-by-u...  1941-01-27T00:00:00Z
# 14  https://api.europeana.eu/api/v2/thumbnail-by-u...  1940-10-07T00:00:00Z
# 15  https://api.europeana.eu/api/v2/thumbnail-by-u...  1903-11-14T00:00:00Z
# 16  https://api.europeana.eu/api/v2/thumbnail-by-u...  1940-12-30T00:00:00Z
# 17  https://api.europeana.eu/api/v2/thumbnail-by-u...  1940-09-09T00:00:00Z
# 18  https://api.europeana.eu/api/v2/thumbnail-by-u...  1941-04-07T00:00:00Z
# 19  https://api.europeana.eu/api/v2/thumbnail-by-u...  1940-08-19T00:00:00Z
# 20  https://api.europeana.eu/api/v2/thumbnail-by-u...  1941-03-10T00:00:00Z
# 21  https://api.europeana.eu/api/v2/thumbnail-by-u...  1941-01-20T00:00:00Z
# 22  https://api.europeana.eu/api/v2/thumbnail-by-u...  1941-04-14T00:00:00Z
# 23  https://api.europeana.eu/api/v2/thumbnail-by-u...  1941-02-24T00:00:00Z
#
#                                               license  \
# 0   http://creativecommons.org/publicdomain/mark/1.0/
# 1   http://creativecommons.org/publicdomain/mark/1.0/
# 2   http://creativecommons.org/publicdomain/mark/1.0/
# 3   http://creativecommons.org/publicdomain/mark/1.0/
# 4   http://creativecommons.org/publicdomain/mark/1.0/
# 5   http://creativecommons.org/publicdomain/mark/1.0/
# 6   http://creativecommons.org/publicdomain/mark/1.0/
# 7   http://creativecommons.org/publicdomain/mark/1.0/
# 8   http://creativecommons.org/publicdomain/mark/1.0/
# 9   http://creativecommons.org/publicdomain/mark/1.0/
# 10  http://creativecommons.org/publicdomain/mark/1.0/
# 11  http://creativecommons.org/publicdomain/mark/1.0/
# 12  http://creativecommons.org/publicdomain/mark/1.0/
# 13  http://creativecommons.org/publicdomain/mark/1.0/
# 14  http://creativecommons.org/publicdomain/mark/1.0/
# 15  http://creativecommons.org/publicdomain/mark/1.0/
# 16  http://creativecommons.org/publicdomain/mark/1.0/
# 17  http://creativecommons.org/publicdomain/mark/1.0/
# 18  http://creativecommons.org/publicdomain/mark/1.0/
# 19  http://creativecommons.org/publicdomain/mark/1.0/
# 20  http://creativecommons.org/publicdomain/mark/1.0/
# 21  http://creativecommons.org/publicdomain/mark/1.0/
# 22  http://creativecommons.org/publicdomain/mark/1.0/
# 23  http://creativecommons.org/publicdomain/mark/1.0/
#
#                                  typem language  \
# 0   http://schema.org/PublicationIssue       lv
# 1   http://schema.org/PublicationIssue       lv
# 2   http://schema.org/PublicationIssue       lv
# 3   http://schema.org/PublicationIssue       de
# 4   http://schema.org/PublicationIssue       lv
# 5   http://schema.org/PublicationIssue       lv
# 6   http://schema.org/PublicationIssue       lv
# 7   http://schema.org/PublicationIssue       lv
# 8   http://schema.org/PublicationIssue       lv
# 9   http://schema.org/PublicationIssue       lv
# 10  http://schema.org/PublicationIssue       lv
# 11  http://schema.org/PublicationIssue       lv
# 12  http://schema.org/PublicationIssue       lv
# 13  http://schema.org/PublicationIssue       lv
# 14  http://schema.org/PublicationIssue       lv
# 15  http://schema.org/PublicationIssue       de
# 16  http://schema.org/PublicationIssue       lv
# 17  http://schema.org/PublicationIssue       lv
# 18  http://schema.org/PublicationIssue       lv
# 19  http://schema.org/PublicationIssue       lv
# 20  http://schema.org/PublicationIssue       lv
# 21  http://schema.org/PublicationIssue       lv
# 22  http://schema.org/PublicationIssue       lv
# 23  http://schema.org/PublicationIssue       lv
#
#                                           fulltextUrl  \
# 0   https://www.europeana.eu/api/fulltext/9200303/...
# 1   https://www.europeana.eu/api/fulltext/9200303/...
# 2   https://www.europeana.eu/api/fulltext/9200303/...
# 3   https://www.europeana.eu/api/fulltext/9200303/...
# 4   https://www.europeana.eu/api/fulltext/9200303/...
# 5   https://www.europeana.eu/api/fulltext/9200303/...
# 6   https://www.europeana.eu/api/fulltext/9200303/...
# 7   https://www.europeana.eu/api/fulltext/9200303/...
# 8   https://www.europeana.eu/api/fulltext/9200303/...
# 9   https://www.europeana.eu/api/fulltext/9200303/...
# 10  https://www.europeana.eu/api/fulltext/9200303/...
# 11  https://www.europeana.eu/api/fulltext/9200303/...
# 12  https://www.europeana.eu/api/fulltext/9200303/...
# 13  https://www.europeana.eu/api/fulltext/9200303/...
# 14  https://www.europeana.eu/api/fulltext/9200303/...
# 15  https://www.europeana.eu/api/fulltext/9200303/...
# 16  https://www.europeana.eu/api/fulltext/9200303/...
# 17  https://www.europeana.eu/api/fulltext/9200303/...
# 18  https://www.europeana.eu/api/fulltext/9200303/...
# 19  https://www.europeana.eu/api/fulltext/9200303/...
# 20  https://www.europeana.eu/api/fulltext/9200303/...
# 21  https://www.europeana.eu/api/fulltext/9200303/...
# 22  https://www.europeana.eu/api/fulltext/9200303/...
# 23  https://www.europeana.eu/api/fulltext/9200303/...
#
#                                           manifestUrl  \
# 0   https://iiif.europeana.eu/presentation//920030...
# 1   https://iiif.europeana.eu/presentation//920030...
# 2   https://iiif.europeana.eu/presentation//920030...
# 3   https://iiif.europeana.eu/presentation//920030...
# 4   https://iiif.europeana.eu/presentation//920030...
# 5   https://iiif.europeana.eu/presentation//920030...
# 6   https://iiif.europeana.eu/presentation//920030...
# 7   https://iiif.europeana.eu/presentation//920030...
# 8   https://iiif.europeana.eu/presentation//920030...
# 9   https://iiif.europeana.eu/presentation//920030...
# 10  https://iiif.europeana.eu/presentation//920030...
# 11  https://iiif.europeana.eu/presentation//920030...
# 12  https://iiif.europeana.eu/presentation//920030...
# 13  https://iiif.europeana.eu/presentation//920030...
# 14  https://iiif.europeana.eu/presentation//920030...
# 15  https://iiif.europeana.eu/presentation//920030...
# 16  https://iiif.europeana.eu/presentation//920030...
# 17  https://iiif.europeana.eu/presentation//920030...
# 18  https://iiif.europeana.eu/presentation//920030...
# 19  https://iiif.europeana.eu/presentation//920030...
# 20  https://iiif.europeana.eu/presentation//920030...
# 21  https://iiif.europeana.eu/presentation//920030...
# 22  https://iiif.europeana.eu/presentation//920030...
# 23  https://iiif.europeana.eu/presentation//920030...
#
#                                              fulltext
# 0   sjg?diues^C?O-'^uo? 5.?!?6??qo\nVISU ZEMJU PRO...
# 1   Oblig?ts konfroleksempl?rs\n??? ?*?$? »m>t?>ne...
# 2   P/7 i ? / ( L-J Lix3 U\A :U Nr. 24 Pirmdien, 7...
# 3   ???????? ??????.\nAbonn«m»»tspr«is! jährlich 2...
# 4   Vi*u *emfrt pttlef?tMh #«?1«?^/1??#||\nnr. 58 ...
# 5   V\nVisu zemju prolet?rie?i/ savienoj?etiesl\n?...
# 6   VISU ZEMJU PROLET?RIE?I, SAVIENOJIETIES!\nReda...
# 7   i\nVisu l?m?u proletarleSf/ scvleno?atte?l ??2...
# 8   ?? ?EMJU PROVSTjf?tTZST, SAVIENOJIETIES!\nReda...
# 9   Visu ????\nRedakci|a, kantoris un ekspedicija ...
# 10  "?\nOoligafs i<onfro!eksempl?rs |\nvisu 'zemju...
# 11  VISU ZEMJU PROLET?RIE?I, SAVIENOJIETIESt\n? p ...
# 12  sjg?diues^C?O-'^uo? 5.?!?6??qo\nVISU ZEMJU PRO...
# 13  Oblig?ts konfroleksempl?rs\n??? ?*?$? »m>t?>ne...
# 14  P/7 i ? / ( L-J Lix3 U\A :U Nr. 24 Pirmdien, 7...
# 15  ???????? ??????.\nAbonn«m»»tspr«is! jährlich 2...
# 16  Vi*u *emfrt pttlef?tMh #«?1«?^/1??#||\nnr. 58 ...
# 17  V\nVisu zemju prolet?rie?i/ savienoj?etiesl\n?...
# 18  VISU ZEMJU PROLET?RIE?I, SAVIENOJIETIES!\nReda...
# 19  i\nVisu l?m?u proletarleSf/ scvleno?atte?l ??2...
# 20  ?? ?EMJU PROVSTjf?tTZST, SAVIENOJIETIES!\nReda...
# 21  Visu ????\nRedakci|a, kantoris un ekspedicija ...
# 22  "?\nOoligafs i<onfro!eksempl?rs |\nvisu 'zemju...
# 23  VISU ZEMJU PROLET?RIE?I, SAVIENOJIETIESt\n? p ...

# %% [markdown]
# ## Showing the thumbnails as a gallery
#
# Once we have queried the repository and we have the metadata as a CSV file, let's show the results as a thumbnail gallery

# %%
from IPython.display import HTML, Image

def _src_from_data(data):
    """Base64 encodes image bytes for inclusion in an HTML img element"""
    img_obj = Image(data=data)
    for bundle in img_obj._repr_mimebundle_():
        for mimetype, b64value in bundle.items():
            if mimetype.startswith('image/'):
                return f'data:{mimetype};base64,{b64value}'

def gallery(images, row_height='auto'):
    """Shows a set of images in a gallery that flexes with the width of the notebook.
    
    Parameters
    ----------
    images: list of str or bytes
        URLs or bytes of images to display

    row_height: str
        CSS height value to assign to all images. Set to 'auto' by default to show images
        with their native dimensions. Set to a value like '250px' to make all rows
        in the gallery equal height.
    """
    figures = []
    for image in images:
        if isinstance(image, bytes):
            src = _src_from_data(image)
            caption = ''
        else:
            src = image
            caption = f'<figcaption style="font-size: 0.6em">{image}</figcaption>'
        figures.append(f'''
            <figure style="margin: 5px !important;">
              <img src="{src}" style="height: {row_height}">
              
            </figure>
        ''')
    return HTML(data=f'''
        <div style="display: flex; flex-flow: row wrap; text-align: center;">
        {''.join(figures)}
        </div>
    ''')

# %%
#gallery(urls, row_height='150px')
gallery(df['thumbnail'], row_height='150px')
# Out:
#         <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2FISX3U6N2H3KPUERYIVDWV246R5T5O64ECVYSVHOINB2PCCYTJ2QA%2Fpresentation_images%2Fc4a4f270-0212-11e6-b68d-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FSarkanais_Sports%2F1941%2F02%2F17%2Fp_001_sasp1941n020_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2FZATHOZBFH5MGLINFUU56VF4JM22WTM7USROYDFLVSHOZ5A7GKZCA%2Fpresentation_images%2Fbf24c890-0210-11e6-b68d-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FSarkanais_Sports%2F1941%2F01%2F27%2Fp_001_sasp1941n011_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2F7F6O74Z2CVOSSIQA2OGETFSKEDFCF3TKDKJK4S3KTIFDHU4PMYDA%2Fpresentation_images%2F950fed00-0210-11e6-b68d-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FSarkanais_Sports%2F1940%2F10%2F07%2Fp_001_sasp1940n024_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2FVSZ72MHXV5FNZTDLA4FADKBQL6ACHJVRU4KZ4FPXTH6OXWQ7WTCQ%2Fpresentation_images%2F1c4f1280-032b-11e6-95c4-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FWindausche_Zeitung%2F1903%2F11%2F14%2Fp_001_wize1903n45_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2F3OOVZU5RJBOWLQVOOLZOOFCXZIA2GN4ATVFLTEY3H5Q5FQJOVWZQ%2Fpresentation_images%2F1e6a03f0-0212-11e6-b68d-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FSarkanais_Sports%2F1940%2F12%2F30%2Fp_001_sasp1940n058_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2FVTQ5S64IJBHFECJ3IPSXNCZUWSBUCNOOFRCX7JQDRZNSZWW2P5MA%2Fpresentation_images%2F536f1ff0-0211-11e6-b68d-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FSarkanais_Sports%2F1940%2F09%2F09%2Fp_001_sasp1940n012_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2FUQ4TTIXBGNKKRZVY4C75NCELZQ4YA2EOJ6KEP6SFFHKR6Q2TBKQQ%2Fpresentation_images%2F12e923a0-0210-11e6-b68d-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FSarkanais_Sports%2F1941%2F04%2F07%2Fp_001_sasp1941n041_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2FUNNDG2QALV7KE5XAIHRF74EEBM2PI2CFL267JMUGC6NLUK4ZZEIA%2Fpresentation_images%2F80468170-0212-11e6-b68d-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FSarkanais_Sports%2F1940%2F08%2F19%2Fp_001_sasp1940n003_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2FJ4YXS64E2WAE74GYN5F7KGYD676H5B4GXZOKGCUKVEKNHMF7NWGQ%2Fpresentation_images%2F01121280-0211-11e6-b68d-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FSarkanais_Sports%2F1941%2F03%2F10%2Fp_001_sasp1941n029_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2FYSIMXDM6JV5XCBXUT4RYHGTJNOHRWSAENJJ3SGX3E4BSTBJDHO3Q%2Fpresentation_images%2F94018a40-0210-11e6-b68d-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FSarkanais_Sports%2F1941%2F01%2F20%2Fp_001_sasp1941n009_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2FH33L3AWEWNCRBC6Z2WYONHNRZ3FRUF2ZVCXQAY2E6B6IXIOOGOCA%2Fpresentation_images%2Fac0bac70-020f-11e6-b68d-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FSarkanais_Sports%2F1941%2F04%2F14%2Fp_001_sasp1941n044_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2FLIAGKQMOREBVF33PNDJ43PJ5EJC4ULPOHOVSDPHGVGF6UW3GM54Q%2Fpresentation_images%2F0c0ad710-0213-11e6-b68d-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FSarkanais_Sports%2F1941%2F02%2F24%2Fp_001_sasp1941n023_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2FISX3U6N2H3KPUERYIVDWV246R5T5O64ECVYSVHOINB2PCCYTJ2QA%2Fpresentation_images%2Fc4a4f270-0212-11e6-b68d-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FSarkanais_Sports%2F1941%2F02%2F17%2Fp_001_sasp1941n020_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2FZATHOZBFH5MGLINFUU56VF4JM22WTM7USROYDFLVSHOZ5A7GKZCA%2Fpresentation_images%2Fbf24c890-0210-11e6-b68d-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FSarkanais_Sports%2F1941%2F01%2F27%2Fp_001_sasp1941n011_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2F7F6O74Z2CVOSSIQA2OGETFSKEDFCF3TKDKJK4S3KTIFDHU4PMYDA%2Fpresentation_images%2F950fed00-0210-11e6-b68d-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FSarkanais_Sports%2F1940%2F10%2F07%2Fp_001_sasp1940n024_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail-by-url.json?uri=https%3A%2F%2Fiiif.europeana.eu%2Fimage%2FVSZ72MHXV5FNZTDLA4FADKBQL6ACHJVRU4KZ4FPXTH6OXWQ7WTCQ%2Fpresentation_images%2F1c4f1280-032b-11e6-95c4-fa163e60dd72%2Fnode-1%2Fimage%2FNLL%2FWindausche_Zeitung%2F1903%2F11%2F14%2Fp_001_wize1903n45_001%2Ffull%2Ffull%2F0%2Fdefault.jpg&type=TEXT" style="height: 150px">
#
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://api.europeana.eu/api/v2/thumbnail
